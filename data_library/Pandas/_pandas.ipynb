# %% [markdown]
# #### Creator: Wes McKinney, a data scientist and software developer, created pandas in 2008

# %%
import pandas as pd

# %%
df = pd.read_csv("sales_data_sample.csv", encoding="latin1")
print(df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df = pd.read_excel("SampleSuperstore.xlsx", sheet_name="Orders")
print(df)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
pd2 = pd.read_json("sample_Data.json")
print(pd2)
# Out:
#     id                                               name  \
# 0    1                                    Apple iPhone 12
# 1    2                                 Samsung Galaxy S21
# 2    3                                 Sony PlayStation 5
# 3    4                  LG OLED55CXPUA 55-inch 4K OLED TV
# 4    5        Bose QuietComfort 35 II Wireless Headphones
# 5    6                          Fitbit Versa 3 Smartwatch
# 6    7                             KitchenAid Stand Mixer
# 7    8                 Dyson V11 Absolute Cordless Vacuum
# 8    9                         Ninja Foodi Smart XL Grill
# 9   10                    Canon EOS Rebel T8i DSLR Camera
# 10  11                                  Apple AirPods Pro
# 11  12        Bose QuietComfort 35 II Wireless Headphones
# 12  13                    Fitbit Charge 4 Fitness Tracker
# 13  14                              Samsung Galaxy Watch3
# 14  15  Sony WH-1000XM4 Wireless Noise-Cancelling Head...
# ...

# %%
data = {
    "Name": ["Jai", "Princi", "Gaurav", "Anuj"],
    "Age": [27, 24, 22, 32],
    "City": ["Delhi", "Kanpur", "Allahabad", "Kannauj"],
}

df = pd.DataFrame(data)  
print(df)

# df.to_csv("Output.csv",index=False)
df.to_excel("output.xlsx", engine="openpyxl", index=False)
# df.to_json("output.json",index=False)
# Out:
#      Name  Age       City
# 0     Jai   27      Delhi
# 1  Princi   24     Kanpur
# 2  Gaurav   22  Allahabad
# 3    Anuj   32    Kannauj

# %%
df = pd.read_json("sample_Data.json")
# print(df)


#head() and tail() default 5 rows
print("Display 10 rows of first")
print(df.head(10))

print("\nDisplay 10 rows of last")
print(df.tail(10))
# Out:
# Display 10 rows of first
#    id                                         name  \
# 0   1                              Apple iPhone 12
# 1   2                           Samsung Galaxy S21
# 2   3                           Sony PlayStation 5
# 3   4            LG OLED55CXPUA 55-inch 4K OLED TV
# 4   5  Bose QuietComfort 35 II Wireless Headphones
#
#                                          description    price     category  \
# 0  The Apple iPhone 12 features a 6.1-inch Super ...   999.00  Electronics
# 1  The Samsung Galaxy S21 features a 6.2-inch Dyn...   799.00  Electronics
# 2  The Sony PlayStation 5 features an AMD Zen 2-b...   499.99  Electronics
# 3  The LG OLED55CXPUA 55-inch 4K OLED TV features...  1599.99  Electronics
# 4  The Bose QuietComfort 35 II Wireless Headphone...   299.00  Electronics
#
#                                                image
# 0  https://www.apple.com/newsroom/images/product/...
# 1  https://images.samsung.com/is/image/samsung/p6...
# ...

# %%
'''
1 - column, rows? 
2 - what type of
3 - missing data

info() - summarise your data set
method

1- number of rows and columns
2 - column name
3 - ini64 null counts
4 - non null counts
5 - memory usage of the data frame
'''

df = pd.read_json("sample_Data.json")

print("Display the info of data set")
print(df.info())
# Out:
# Display the info of data set
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           20 non-null     int64
#  1   name         20 non-null     object
#  2   description  20 non-null     object
#  3   price        20 non-null     float64
#  4   category     20 non-null     object
#  5   image        20 non-null     object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.1+ KB
# None

# %%
#check small data info

data = {
    "Name": ["Jai", "Princi", "Gaurav", "Anuj"],
    "Age": [27, 24, 22, 32],
    "City": ["Delhi", "Kanpur", "Allahabad", "Kannauj"],
}

df = pd.DataFrame(data)

print("Displaying the info of data set: ")
print(df.info())
# Out:
# Displaying the info of data set:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes
# None

# %%
#describe - 

#step -1 sample data frame
'''
describe show the information of data which is -
count  
mean   
std    
min    
25%    
50%    
75%    
max
'''

data = {
    "Name":["Ram","Shyam","Ghanshym","Dhanshyam","Aditya","Jagdish","Raj","Simran"],
    "Age":[28,20,39,32,52,60,25,63],
    "Salary":[50000,60000,45000,49000,70000,48000,35000,22000],
    "Performance Score":[85,98,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

print("Sample data frame: ")
print(df)
print("Descriptive Statistics")
print(df.describe())
# Out:
# Sample data frame:
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   20   60000                 98
# 2   Ghanshym   39   45000                 78
# 3  Dhanshyam   32   49000                 92
# 4     Aditya   52   70000                 88
# 5    Jagdish   60   48000                 95
# 6        Raj   25   35000                 80
# 7     Simran   63   22000                 89
# Descriptive Statistics
#              Age        Salary  Performance Score
# count   8.000000      8.000000           8.000000
# mean   39.875000  47375.000000          88.125000
# std    16.504869  14559.606549           6.957781
# min    20.000000  22000.000000          78.000000
# 25%    27.250000  42500.000000          83.750000
# 50%    35.500000  48500.000000          88.500000
# 75%    54.000000  52500.000000          92.750000
# max    63.000000  70000.000000          98.000000

# %%
#shape ad columns

data = {
    "Name":["Ram","Shyam","Ghanshym","Dhanshyam","Aditya","Jagdish","Raj","Simran"],
    "Age":[28,20,39,32,52,60,25,63],
    "Salary":[50000,60000,45000,49000,70000,48000,35000,22000],
    "Performance Score":[85,98,78,92,88,95,80,89]
}


df = pd.DataFrame(data)
print(f"Shape: {df.shape}")  #how many rows and columns
print(f"Columns: {df.columns}")
# Out:
# Shape: (8, 4)
# Columns: Index(['Name', 'Age', 'Salary', 'Performance Score'], dtype='object')

# %%
'''
1- select specific column
2- filter rows
3- combine multiple conditions

1- square brackets
2- boolean conditions

selecting columns
1- a series
2- dataframe mulitple columns of data

column = df["column Name"]
subset = df["col1","col2","..."]


filtering rows
boolean indexing

#based on a single condition in rows
filtered_rows = df[df["Salary"] > 50000]

#combine multiple conditions
filtered_rows = df[(df["salary] > 50000) & (df["column2"] < 80000)]
'''

data = {
    "Name":["Ram","Shyam","Ghanshym","Dhanshyam","Aditya","Jagdish","Raj","Simran"],
    "Age":[28,20,39,32,52,60,25,63],
    "Salary":[50000,60000,45000,49000,70000,48000,35000,22000],
    "Performance Score":[85,98,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

print("Sample DataFrame")
print(df)

print("\n\nNames (single column returns series)")
print(df["Name"])

#selecting multiple columns
subset = df[["Name", "Salary"]]
print("\n\nSubset with Name and salary")
print(subset)
# Out:
# Sample DataFrame
#         Name  Age  Salary  Performance Score
# 0        Ram   28   50000                 85
# 1      Shyam   20   60000                 98
# 2   Ghanshym   39   45000                 78
# 3  Dhanshyam   32   49000                 92
# 4     Aditya   52   70000                 88
# 5    Jagdish   60   48000                 95
# 6        Raj   25   35000                 80
# 7     Simran   63   22000                 89
#
#
# Names (single column returns series)
# 0          Ram
# 1        Shyam
# 2     Ghanshym
# 3    Dhanshyam
# 4       Aditya
# 5      Jagdish
# 6          Raj
# 7       Simran
# Name: Name, dtype: object
#
#
# Subset with Name and salary
#         Name  Salary
# 0        Ram   50000
# 1      Shyam   60000
# 2   Ghanshym   45000
# 3  Dhanshyam   49000
# 4     Aditya   70000
# 5    Jagdish   48000
# 6        Raj   35000
# 7     Simran   22000

# %%
#rows filter

data = {
    "Name":["Ram","Shyam","Ghanshym","Dhanshyam","Aditya","Jagdish","Raj","Simran"],
    "Age":[28,34,22,30,29,40,25,32],
    "Salary":[50000,60000,45000,52000,49000,70000,48000,58000],
    "Performance_Score":[85,98,78,92,88,95,80,89]
}

df = pd.DataFrame(data)

high_salary = df[df["Salary"] > 50000]
print("Employees with salary > 50000")
print(high_salary)

#multiple conditions
filtered = df[(df['Age'] > 30) & (df["Salary"] > 50000)]
print("\n\nEmployees list age > 30 and salary > 50000")
print(filtered)


#uisng OR condition
filtered_or = df[(df["Age"] > 35) | (df["Performance_Score"] > 90)]
print("\n\nEmployees older than 35 or performance score above 90")
print(filtered_or)
# Out:
# Employees with salary > 50000
#         Name  Age  Salary  Performance_Score
# 1      Shyam   34   60000                 98
# 3  Dhanshyam   30   52000                 92
# 5    Jagdish   40   70000                 95
# 7     Simran   32   58000                 89
#
#
# Employees list age > 30 and salary > 50000
#       Name  Age  Salary  Performance_Score
# 1    Shyam   34   60000                 98
# 5  Jagdish   40   70000                 95
# 7   Simran   32   58000                 89
#
#
# Employees older than 35 or performance score above 90
#         Name  Age  Salary  Performance_Score
# 1      Shyam   34   60000                 98
# 3  Dhanshyam   30   52000                 92
# 5    Jagdish   40   70000                 95
